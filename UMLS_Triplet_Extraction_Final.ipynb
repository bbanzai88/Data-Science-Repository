# %% [markdown]
# <a href="https://colab.research.google.com/github/bbanzai88/Data-Science-Repository/blob/main/UMLS_Triplet_Extraction_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook takes a file with a doi and  an abstract. For each sentence, it identifies the UMLS related words. If there are two such words in a sentence and a verb in between them, it identifies a triple consisting of a subject, verb, and object for each abstract. When  running each cell, look at  the result. If the result requests restart run time please do so or the rest of the code will not run correctly.

# %%
# !pip install scispacy
# !pip install allennlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scispacy in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Requirement already satisfied: nmslib>=1.7.3.6 in /usr/local/lib/python3.7/dist-packages (from scispacy) (2.1.1)
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.7/dist-packages (from scispacy) (1.0.2)
# Collecting spacy<3.5.0,>=3.4.0
#   Using cached spacy-3.4.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.3 MB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scispacy) (1.21.6)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scispacy) (2.28.1)
# Requirement already satisfied: conllu in /usr/local/lib/python3.7/dist-packages (from scispacy) (4.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from scispacy) (1.1.0)
# Requirement already satisfied: pysbd in /usr/local/lib/python3.7/dist-packages (from scispacy) (0.3.4)
# Requirement already satisfied: pybind11<2.6.2 in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy) (2.6.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy) (5.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.10)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.3->scispacy) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.3->scispacy) (3.1.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (3.0.7)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (0.6.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (3.0.10)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (1.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.0.6)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (4.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.4.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.0.8)
# Collecting thinc<8.2.0,>=8.1.0
#   Using cached thinc-8.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (803 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (0.10.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (0.4.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (4.64.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (1.0.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (21.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.4.0->scispacy) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->scispacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->scispacy) (5.2.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->scispacy) (0.0.1)
# Requirement already satisfied: blis<0.10.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->scispacy) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->scispacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->scispacy) (2.0.1)
# Installing collected packages: thinc, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.17
#     Uninstalling thinc-8.0.17:
#       Successfully uninstalled thinc-8.0.17
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.3.1
#     Uninstalling spacy-3.3.1:
#       Successfully uninstalled spacy-3.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# allennlp 2.10.0 requires spacy<3.4,>=2.1.0, but you have spacy 3.4.1 which is incompatible.
# Successfully installed spacy-3.4.1 thinc-8.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: allennlp in /usr/local/lib/python3.7/dist-packages (2.10.0)
# Requirement already satisfied: base58>=2.1.1 in /usr/local/lib/python3.7/dist-packages (from allennlp) (2.1.1)
# Requirement already satisfied: pytest>=6.2.5 in /usr/local/lib/python3.7/dist-packages (from allennlp) (7.1.3)
# Requirement already satisfied: sentencepiece>=0.1.96 in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.1.97)
# Requirement already satisfied: tensorboardX>=1.2 in /usr/local/lib/python3.7/dist-packages (from allennlp) (2.5.1)
# Requirement already satisfied: numpy>=1.21.4 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.21.6)
# Requirement already satisfied: traitlets>5.1.1 in /usr/local/lib/python3.7/dist-packages (from allennlp) (5.4.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.0.2)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.7.3)
# Requirement already satisfied: h5py>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (3.7.0)
# Requirement already satisfied: torchvision<0.13.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.12.0)
# Requirement already satisfied: lmdb>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.3.0)
# Requirement already satisfied: tqdm>=4.62 in /usr/local/lib/python3.7/dist-packages (from allennlp) (4.64.1)
# Requirement already satisfied: protobuf==3.20.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (3.20.0)
# Requirement already satisfied: rich==12.1 in /usr/local/lib/python3.7/dist-packages (from allennlp) (12.1.0)
# Requirement already satisfied: more-itertools>=8.12.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (8.14.0)
# Requirement already satisfied: cached-path<1.2.0,>=1.1.3 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.1.5)
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.4.2)
# Requirement already satisfied: torch<1.12.0,>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.11.0)
# Requirement already satisfied: fairscale==0.4.6 in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.4.6)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.7/dist-packages (from allennlp) (2.28.1)
# Requirement already satisfied: jsonnet>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.18.0)
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from allennlp) (3.7)
# Requirement already satisfied: wandb<0.13.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.12.21)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.3.5.1)
# Requirement already satisfied: transformers<4.21,>=4.1 in /usr/local/lib/python3.7/dist-packages (from allennlp) (4.20.1)
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.1.0)
# Requirement already satisfied: filelock<3.8,>=3.3 in /usr/local/lib/python3.7/dist-packages (from allennlp) (3.7.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.0.53)
# Requirement already satisfied: huggingface-hub>=0.0.16 in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.8.1)
# Collecting spacy<3.4,>=2.1.0
#   Using cached spacy-3.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich==12.1->allennlp) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich==12.1->allennlp) (2.6.1)
# Requirement already satisfied: typing-extensions<5.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from rich==12.1->allennlp) (4.1.1)
# Requirement already satisfied: boto3<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from cached-path<1.2.0,>=1.1.3->allennlp) (1.24.78)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /usr/local/lib/python3.7/dist-packages (from cached-path<1.2.0,>=1.1.3->allennlp) (2.5.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.6.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.78 in /usr/local/lib/python3.7/dist-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.27.78)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.78->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.78->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.26.12)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.35.0)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.3.3)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.3.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.31.6)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.56.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2022.2.1)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (21.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.2.8)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.7/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.5.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp) (4.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp) (6.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp) (2022.6.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.4.8)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp) (22.1.0)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp) (1.11.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.0.16->allennlp) (3.8.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.1->allennlp) (3.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (3.0.10)
# Collecting thinc<8.1.0,>=8.0.14
#   Using cached thinc-8.0.17-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (660 kB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (0.7.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (2.4.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (1.0.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (0.6.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (3.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (1.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (1.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (3.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp) (2.11.3)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4,>=2.1.0->allennlp) (5.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision<0.13.0,>=0.8.1->allennlp) (7.1.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.21,>=4.1->allennlp) (0.12.1)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (2.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.9.8)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.3.2)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.0.9)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (5.4.8)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (0.1.2)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (3.1.27)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (0.4.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp) (5.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4,>=2.1.0->allennlp) (2.0.1)
# Installing collected packages: thinc, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.1
#     Uninstalling thinc-8.1.1:
#       Successfully uninstalled thinc-8.1.1
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.1
#     Uninstalling spacy-3.4.1:
#       Successfully uninstalled spacy-3.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scispacy 0.5.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.3.1 which is incompatible.
# en-core-web-sm 3.4.0 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.3.1 which is incompatible.
# en-core-sci-sm 0.5.1 requires spacy<3.5.0,>=3.4.1, but you have spacy 3.3.1 which is incompatible.
# Successfully installed spacy-3.3.1 thinc-8.0.17

# %%
import os
import spacy
from scispacy.umls_linking import UmlsEntityLinker
from allennlp.predictors.predictor import Predictor
import json
import re

# %%
def check_uml(ent):
    '''
    Get uml concept
    :param entity:
    :return:
    '''
    uml_ent_cls = ent._.umls_ents
    # print (uml_ent_cls)
    # Check entities in uml with confidence = 100
    entity = [e for e, s in uml_ent_cls if s == 1.0]
    # print ('Found UML Entity:' + str(entity))
    try:
        # print(entity[0])
        return entity[0]
    except Exception:
        return []

# %%
def get_oie(sentence, oie_pred, entities, relation):
    '''
    Get the information in form of triples
    :param sentence: original sentence
    :param oie_pred: ie prediction tags
    :param entities: list of entities predicted using spacy
    :param relation: relations predicted from oie, basically the verb
    :return: multiple triples 
    '''
    triples = []
    arg0 = [w for j, w in enumerate(sentence.split()) if 'ARG0' in oie_pred[j]]
    arg1 = [w for j, w in enumerate(sentence.split()) if 'ARG1' in oie_pred[j]]
    subjects = [u for e, u in entities if str(e) in ' '.join(arg0)]
    objects = [u for e, u in entities if str(e) in ' '.join(arg1)]
    if subjects and objects:
        for s in subjects:
            for o in objects:
                triples.append([s, relation, o])
    return triples


def get_triples(sentence):
    '''
    Get triples using OIE
    :param sentence: sentence
    :return:
    '''
    predicted_ie = predictor.predict(sentence)
    entities = get_entities(sentence)
    for p_i in predicted_ie['verbs']:
        relation = p_i['verb']
        oie_tag = p_i['tags']
        triples = get_oie(sentence, oie_tag, entities, relation)
    if 'triples' in locals():
        # print (triples)
        # triples = [t for triple in triples for t in triple]
        # print (triples)
        return triples
    else:
        return []

# %%
def get_entities(sentence):
    # Get entity labels and uml entities
    # print ('Getting entities for sentence:'+sentence)
    doc = nlp(sentence)
    entities = doc.ents
    # entity_text= [e.text for e in entities]
    uml_ent = [(e.text, check_uml(e)) for e in entities]
    uml_ent = [(e, uml_e) for e, uml_e in uml_ent if uml_e]
    return uml_ent


def get_paper_triples(abstract,doi):
    #write triples into text
    # print (json_file)
    #with open(json_file, 'r') as f:
    paper_text= abstract
    paper_text = ''.join(t for t in paper_text)
    for sent in paper_text.split('.'):
        print ('Getting triples for text')
        try:
           triples = get_triples(sent)
           if triples:
            print ('Found triples:'+str(len(triples)))
            for t in triples:
                if t not in all_triples:
                    all_triples.append(t)
                    print (t)
                    print ('Writing triples to file, length of all triples ='+str(len(all_triples)))
                    out_kg.write(t[0]+'\t'+t[1]+'\t'+t[2]+'\n')
        except KeyError as e:
                continue

def add_bi(abstractList, doiList):
    i = 0
    table= {"doi":[], "triples":[]}
    for doc in nlp_bi.pipe(abstractList):
        doi = doiList[i]
        for x in doc.ents:
          table["doi"].append(doi)
          table["Entity"].append(x.text)
          table["Class"].append(x.label_)
        i +=1
    return table

# %%
import spacy
spacy.load('en_core_web_sm')
from spacy.lang.en import English
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:837: UserWarning: [W095] Model 'en_core_web_sm' (3.4.0) was trained with spaCy v3.4 and may not be 100% compatible with the current version (3.3.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
import pandas as pd

#Read in file
meta_dfu = pd.read_csv("/content/sample_data/PM_dfu.csv",sep=",", error_bad_lines=False,engine='python')

#Sort out blank abstracts
df = meta_dfu.dropna(subset=['abstract'])

#Create lists
doiList = df['doi'].tolist()
abstractList = df['abstract'].tolist()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# !pip install allennlp-models
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: allennlp-models in /usr/local/lib/python3.7/dist-packages (2.10.0)
# Requirement already satisfied: conllu==4.4.2 in /usr/local/lib/python3.7/dist-packages (from allennlp-models) (4.4.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (from allennlp-models) (2.5.1)
# Requirement already satisfied: word2number>=1.1 in /usr/local/lib/python3.7/dist-packages (from allennlp-models) (1.1)
# Requirement already satisfied: allennlp<2.11,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from allennlp-models) (2.10.0)
# Requirement already satisfied: py-rouge==1.1 in /usr/local/lib/python3.7/dist-packages (from allennlp-models) (1.1)
# Requirement already satisfied: torch<1.12.0,>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from allennlp-models) (1.11.0)
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from allennlp-models) (3.7)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.7/dist-packages (from allennlp-models) (6.1.1)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (1.7.3)
# Requirement already satisfied: more-itertools>=8.12.0 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (8.14.0)
# Requirement already satisfied: cached-path<1.2.0,>=1.1.3 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (1.1.5)
# Requirement already satisfied: filelock<3.8,>=3.3 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (3.7.1)
# Requirement already satisfied: huggingface-hub>=0.0.16 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (0.8.1)
# Requirement already satisfied: base58>=2.1.1 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (2.1.1)
# Requirement already satisfied: h5py>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (3.7.0)
# Requirement already satisfied: jsonnet>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (0.18.0)
# Requirement already satisfied: protobuf==3.20.0 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (3.20.0)
# Requirement already satisfied: torchvision<0.13.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (0.12.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (1.0.2)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (2.28.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (0.0.53)
# Requirement already satisfied: numpy>=1.21.4 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (1.21.6)
# Requirement already satisfied: transformers<4.21,>=4.1 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (4.20.1)
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (1.1.0)
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (0.4.2)
# Requirement already satisfied: pytest>=6.2.5 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (7.1.3)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (0.3.5.1)
# Requirement already satisfied: lmdb>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (1.3.0)
# Requirement already satisfied: spacy<3.4,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (3.3.1)
# Requirement already satisfied: tqdm>=4.62 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (4.64.1)
# Requirement already satisfied: wandb<0.13.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (0.12.21)
# Requirement already satisfied: fairscale==0.4.6 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (0.4.6)
# Requirement already satisfied: tensorboardX>=1.2 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (2.5.1)
# Requirement already satisfied: traitlets>5.1.1 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (5.4.0)
# Requirement already satisfied: sentencepiece>=0.1.96 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (0.1.97)
# Requirement already satisfied: rich==12.1 in /usr/local/lib/python3.7/dist-packages (from allennlp<2.11,>=2.10.0->allennlp-models) (12.1.0)
# Requirement already satisfied: typing-extensions<5.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from rich==12.1->allennlp<2.11,>=2.10.0->allennlp-models) (4.1.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich==12.1->allennlp<2.11,>=2.10.0->allennlp-models) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich==12.1->allennlp<2.11,>=2.10.0->allennlp-models) (2.6.1)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /usr/local/lib/python3.7/dist-packages (from cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (2.5.0)
# Requirement already satisfied: boto3<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (1.24.78)
# Requirement already satisfied: botocore<1.28.0,>=1.27.78 in /usr/local/lib/python3.7/dist-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (1.27.78)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (0.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.78->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (1.26.12)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.78->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (2.8.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (2.3.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (1.35.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (1.31.6)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (2.3.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (1.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (1.56.4)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (2022.2.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (57.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.7/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (1.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp<2.11,>=2.10.0->allennlp-models) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp<2.11,>=2.10.0->allennlp-models) (4.12.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp-models) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp-models) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp-models) (7.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.0->allennlp-models) (0.4.8)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.0->allennlp-models) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.0->allennlp-models) (22.1.0)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.0->allennlp-models) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.0->allennlp-models) (2.0.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.0->allennlp-models) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.0.16->allennlp<2.11,>=2.10.0->allennlp-models) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp<2.11,>=2.10.0->allennlp-models) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp<2.11,>=2.10.0->allennlp-models) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp<2.11,>=2.10.0->allennlp-models) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.1->allennlp<2.11,>=2.10.0->allennlp-models) (3.1.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (3.0.7)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (0.6.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (1.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (0.7.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (2.4.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (1.0.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (8.0.17)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (1.0.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (3.0.10)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (5.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision<0.13.0,>=0.8.1->allennlp<2.11,>=2.10.0->allennlp-models) (7.1.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.21,>=4.1->allennlp<2.11,>=2.10.0->allennlp-models) (0.12.1)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.0->allennlp-models) (1.0.9)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.0->allennlp-models) (2.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.0->allennlp-models) (5.4.8)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.0->allennlp-models) (0.1.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.0->allennlp-models) (0.4.0)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.0->allennlp-models) (3.1.27)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.0->allennlp-models) (1.9.8)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.0->allennlp-models) (1.3.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.0->allennlp-models) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.0->allennlp-models) (5.0.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets->allennlp-models) (0.70.13)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets->allennlp-models) (2022.8.2)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->allennlp-models) (6.0.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets->allennlp-models) (3.8.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets->allennlp-models) (0.18.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets->allennlp-models) (1.3.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets->allennlp-models) (3.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->allennlp-models) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->allennlp-models) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->allennlp-models) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->allennlp-models) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->allennlp-models) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->allennlp-models) (4.0.2)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->allennlp-models) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.0->allennlp-models) (2.0.1)

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz (15.9 MB)
# Collecting spacy<3.5.0,>=3.4.1
#   Using cached spacy-3.4.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.3 MB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.4.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (57.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.0.3)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (4.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.28.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.21.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.3.0)
# Collecting thinc<8.2.0,>=8.1.0
#   Using cached thinc-8.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (803 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.6.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (4.64.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (5.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.10)
# Requirement already satisfied: blis<0.10.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.7.8)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.0.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.0.1)
# Installing collected packages: thinc, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.17
#     Uninstalling thinc-8.0.17:
#       Successfully uninstalled thinc-8.0.17
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.3.1
#     Uninstalling spacy-3.3.1:
#       Successfully uninstalled spacy-3.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# allennlp 2.10.0 requires spacy<3.4,>=2.1.0, but you have spacy 3.4.1 which is incompatible.
# Successfully installed spacy-3.4.1 thinc-8.1.1

# %%
from allennlp.predictors.predictor import Predictor
import allennlp_models.tagging
import pandas as pd
import en_core_web_sm
import spacy
import scispacy

from scispacy.linking import EntityLinker

nlp = spacy.load("en_core_sci_sm")

linker = nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})

meta_dfu = pd.read_csv("/content/sample_data/PM_dfu.csv",sep=",", error_bad_lines=False,engine='python')

#Sort out blank abstracts
df = meta_dfu.dropna(subset=['abstract'])

#Create lists
doiList = df['doi'].tolist()
abstractList = df['abstract'].tolist()

#Sort out blank abstracts
df = meta_dfu.dropna(subset=['abstract'])

#Create lists
doiList = df['doi'].tolist()
abstractList = df['abstract'].tolist()

predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/openie-model.2020.03.26.tar.gz")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:338: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.20.3 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:338: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.20.3 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
def check_uml(ent):
    '''
    Get uml concept
    :param entity:
    :return:
    '''
    uml_ent_cls = ent._.umls_ents
    # print (uml_ent_cls)
    # Check entities in uml with confidence = 100
    entity = [e for e, s in uml_ent_cls if s == 1.0]
    # print ('Found UML Entity:' + str(entity))
    try:
        # print(entity[0])
        return entity[0]
    except Exception:
        return []

# %%
def get_oie(sentence, oie_pred, entities, relation):
    '''
    Get the information in form of triples
    :param sentence: original sentence
    :param oie_pred: ie prediction tags
    :param entities: list of entities predicted using spacy
    :param relation: relations predicted from oie, basically the verb
    :return: multiple triples 
    '''
    triples = []
    arg0 = [w for j, w in enumerate(sentence.split()) if 'ARG0' in oie_pred[j]]
    arg1 = [w for j, w in enumerate(sentence.split()) if 'ARG1' in oie_pred[j]]
    subjects = [u for e, u in entities if str(e) in ' '.join(arg0)]
    objects = [u for e, u in entities if str(e) in ' '.join(arg1)]
    if subjects and objects:
        for s in subjects:
            for o in objects:
                triples.append([s, relation, o])
    return triples


def get_triples(sentence):
    '''
    Get triples using OIE
    :param sentence: sentence
    :return:
    '''
    predicted_ie = predictor.predict(sentence)
    entities = get_entities(sentence)
    for p_i in predicted_ie['verbs']:
        relation = p_i['verb']
        oie_tag = p_i['tags']
        triples = get_oie(sentence, oie_tag, entities, relation)
    if 'triples' in locals():
        # print (triples)
        # triples = [t for triple in triples for t in triple]
        # print (triples)
        return triples
    else:
        return []

# %%
def get_entities(sentence):
    # Get entity labels and uml entities
    # print ('Getting entities for sentence:'+sentence)
    doc = nlp(sentence)
    entities = doc.ents
    # entity_text= [e.text for e in entities]
    uml_ent = [(e.text, check_uml(e)) for e in entities]
    uml_ent = [(e, uml_e) for e, uml_e in uml_ent if uml_e]
    return uml_ent


def get_paper_triples(abstract,doi):
    #write triples into text
    # print (json_file)
    #with open(json_file, 'r') as f:
    paper_text= abstract
    paper_text = ''.join(t for t in paper_text)
    for sent in paper_text.split('.'):
        print ('Getting triples for text')
        try:
           triples = get_triples(sent)
           if triples:
            print ('Found triples:'+str(len(triples)))
            for t in triples:
                if t not in all_triples:
                    all_triples.append(t)
                    print (t)
                    print ('Writing triples to file, length of all triples ='+str(len(all_triples)))
                    out_kg.write(t[0]+'\t'+t[1]+'\t'+t[2]+'\n')
        except KeyError as e:
                continue

# %%
#def get_paper_triples(abstract,doiList,i):
  #  #write triples into text
  #  # print (json_file)
  #  #with open(json_file, 'r') as f:
 #   paper_text= abstract
  #  paper_text = ''.join(t for t in paper_text)
   # i = 0
   # doi = doiList[i]
   # table= {"doi":[], "triples":[]}
    #for sent in paper_text.split('.'):
     #   print ('Getting triples for text')
     #   try:
      #     triples = get_triples(sent)
       #    if triples:
        #    print ('Found triples:'+str(len(triples)))
         #   for t in triples:
         #       if t not in all_triples:
         #           all_triples.append(t)
         #           table["doi"].append(doi)
         #           table['triples'].append(all_triples)
        #            print (t)
        #            i +=1
       #     return table
      #  except KeyError as e:
         #      continue

# %%
#def get_abstract_triples(abstract,doiList,i):
#  paper_text= abstract
#  paper_text = ''.join(t for t in paper_text)
#  doi = doiList[i]
#  all_triples = pd.DataFrame(columns=['doi', 'subject', 'relation', 'object'])
#  table=
#  for sent in paper_text.split('.'):
#        try:
#           triples = get_triples(sent)
#           if len(triples)<2:
#              table["doi"].append(doi)
#              continue
#           else:
#             all_triples.append(triples)
#             table['triples'].append(all_triples)
#             return table
#        except KeyError as e:
#                continue

# %%
#def get_paper_triples(abstract,doiList,i):
 #   #write triples into text
 #   # print (json_file)
 #   #with open(json_file, 'r') as f:
 #   paper_text= abstract
 #   paper_text = ''.join(t for t in paper_text)
 #   i = 0
 #   doi = doiList[i]
 #   table= {"doi":[], "triples":[]}
 #   for sent in paper_text.split('.'):
 #       print ('Getting triples for text')
 #       try:
 #          triples = get_triples(sent)
 #          if triples:
 #           print ('Found triples:'+str(len(triples)))
 #           for t in triples:
 #               if t not in all_triples:
 #                   all_triples.append(t)
 #                   table["doi"].append(doi)
 #                   table['triples'].append(all_triples)
 #                   print (t)
 #                   i +=1
 #           return table
 #       except KeyError as e:
 #               continue

# %%
def get_abstract_triples(abstractList,doiList,i):
 triples=[]
 doi=doiList[i]
 paper_text= abstractList[i]
 paper_text = ''.join(t for t in paper_text)
 table= {"doi":[], "triples":[]}
 for sent in paper_text.split('.'):
           table["doi"].append(doi)
           triple = get_triples(sent)
           table['triples'].append(triple)
           if len(triple)<2:
             continue
           else:
             table['triples'].append(triple)
             table["doi"].append(doi)
 table_df=pd.DataFrame(table)
 table_df2 = table_df.apply(pd.Series.explode).reset_index(drop=True)
 table_df3 = table_df2[table_df2['triples'].notna()]
 #table_df3['Subject', 'Relation', 'Object'] = table_df3.triples.str.split(',',expand=True).tolist()
 #table_df3 = pd.DataFrame(table_df3['triples'].str.split(',').tolist(), columns = ['Subject', 'Relation', 'Object'])
 triple1=pd.DataFrame(table_df3['triples'].tolist(), columns=['Subject', 'Relation', 'Object'])
 triple2=triple1.reset_index(drop=True)
 doi=table_df3['doi'].reset_index(drop=True)
 triple3=pd.concat([doi, triple2], axis=1)
 return triple3
#table_df3

# %%
i=2
get_abstract_triples(abstractList,doiList,i)
# Out:
#                           doi   Subject  Relation    Object
# 0  10.1016/j.bone.2022.116421  C0004048     cause  C0175256
# 1  10.1016/j.bone.2022.116421  C0220825  elevated  C0229671
# 2  10.1016/j.bone.2022.116421  C0220825  elevated  C0428152
# 3  10.1016/j.bone.2022.116421  C0220825  elevated  C0016327
# 4  10.1016/j.bone.2022.116421  C0220825  elevated  C0229671
# 5  10.1016/j.bone.2022.116421  C0220825  elevated  C0428152
# 6  10.1016/j.bone.2022.116421  C0220825  elevated  C0016327

# %%
import tqdm

from allennlp.predictors.predictor import Predictor
import allennlp_models.tagging
import pandas as pd
import en_core_web_sm
import spacy
import scispacy

from scispacy.linking import EntityLinker

nlp = spacy.load("en_core_sci_sm")

linker = nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
# Out:
#   File "<ipython-input-86-73ce3adbd850>", line 34
#     for i in tqdm.tqdm(len(abstractList))
#                                          ^
# SyntaxError: invalid syntax

# %%
import tqdm
from allennlp.predictors.predictor import Predictor
import allennlp_models.tagging
import pandas as pd
import en_core_web_sm
import spacy
import scispacy

from scispacy.linking import EntityLinker

nlp = spacy.load("en_core_sci_sm")

linker = nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})


#fcn subset
meta_dfu = pd.read_csv("/content/sample_data/FCN_Pubmed3.csv",sep=",", error_bad_lines=False,engine='python')

#All
#meta_dfu = pd.read_csv("/content/sample_data/PM_dfu.csv",sep=",", error_bad_lines=False,engine='python')

#Sort out blank abstracts
df = meta_dfu.dropna(subset=['abstract'])

#Create lists
doiList = df['doi'].tolist()
abstractList = df['abstract'].tolist()

#Sort out blank abstracts
df = meta_dfu.dropna(subset=['abstract'])

#Create lists
doiList = df['doi'].tolist()
abstractList = df['abstract'].tolist()

#All_triples = pd.DataFrame(columns=['doi','Subject','Relation','Object'])

predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/openie-model.2020.03.26.tar.gz")

All_triples = pd.DataFrame()

for i in tqdm.tqdm(range(len(abstractList))):
 abstract_triples=get_abstract_triples(abstractList,doiList,i)
 #All_triples=All_triples.append(abstract_triples)
 All_triples=pd.concat([All_triples, abstract_triples])

 All_triples.to_csv('/content/sample_data/All_triples.csv')
# Out:
# 100%|██████████| 491/491 [13:32<00:00,  1.65s/it]

# %%
ll_triples.to_csv('/content/sample_data/All_triples.csv')
# Out:
#                                  doi   Subject   Relation    Object
# 0       10.1016/j.envint.2013.02.005  C1418481  depending  C1418481
# 0   10.1016/j.parkreldis.2022.07.005  C0243144     showed  C0589120
# 1   10.1016/j.parkreldis.2022.07.005  C0205329     showed  C0589120
# 2   10.1016/j.parkreldis.2022.07.005  C0301630     showed  C0589120
# 3   10.1016/j.parkreldis.2022.07.005  C0243144     showed  C0589120
# ..                               ...       ...        ...       ...
# 1       10.1016/j.envint.2017.07.024  C2919405  contained  C0086045
# 2       10.1016/j.envint.2017.07.024  C2919405  contained  C0599638
# 3       10.1016/j.envint.2017.07.024  C2919405  contained  C1418482
# 4       10.1016/j.envint.2017.07.024  C2919405  contained  C0086045
# 5       10.1016/j.envint.2017.07.024  C2919405  contained  C0599638
#
# [1760 rows x 4 columns]
